# %%
# %pip install langchain
# %pip install langchain_community
# %pip install langchain_openai
# %pip install beautifulsoup4
# %pip install openai

# !python3 -m %pip install --upgrade --quiet langchain-openai tiktoken chromadb langchain langchainhub
# !Set env var OPENAI_API_KEY or load from a .env file

import os
os.environ['OPENAI_API_KEY'] = 'sk...'

import dotenv
dotenv.load_dotenv()
# Out:
# ...
#
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: python3.13 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# ...
#
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: python3.13 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# ...
#
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: python3.13 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# ...
#
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: python3.13 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# ...
#
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: python3.13 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# ...

# %%
import requests
import os
import json

# %%
def summarize_interview(model_choice, interview_file):
    """
    Summarizes a user interview using a specified AI model.

    Parameters:
        model_choice (str): Name of the model (must be defined in model_configs.json).
        interview_file (str): Path to the interview transcript file.

    Returns:
        dict: The API response containing the summary.
    """
    # Load model configurations from JSON file
    with open("../config/model_configs.json", "r", encoding="utf-8") as file:
        MODEL_CONFIGS = json.load(file)

    # Replace environment variable placeholders dynamically
    for model in MODEL_CONFIGS:
        if MODEL_CONFIGS[model]["api_key"].startswith("ENV_"):
            env_var = MODEL_CONFIGS[model]["api_key"][4:]  # Remove "ENV_" prefix
            MODEL_CONFIGS[model]["api_key"] = os.getenv(env_var, "MISSING_API_KEY")  # Default if not set

    model_choice = model_choice.lower()

    if model_choice not in MODEL_CONFIGS:
        raise ValueError(f"Invalid model choice '{model_choice}'. Available options: {list(MODEL_CONFIGS.keys())}")

    config = MODEL_CONFIGS[model_choice]

    if config["api_key"] == "MISSING_API_KEY":
        raise ValueError(f"API key for {model_choice} is missing. Set the environment variable and try again.")

    with open(interview_file, "r", encoding="utf-8") as file:
        interview_text = file.read()

    headers = {
        "Authorization": f"Bearer {config['api_key']}",
        "Content-Type": "application/json"
    }

    data = {
        "model": config["model_name"],
        "messages": [
            {"role": "system", "content": "You are an AI assistant that summarizes user interviews."},
            {"role": "user", "content": f"Summarize the following interview transcript:\n\n{interview_text}"}
        ]
    }

    response = requests.post(config["api_url"], json=data, headers=headers)

    return response.json()

# %%
# # Example Usage
# result = summarize_interview("mistral", "../resources/user_interview.txt")
# text = result["choices"][0]["message"]["content"]
# Out:
#  The interview with Sarah Chen, a nurse at a critical care unit (CCU), provides valuable insights into the challenges and pain points associated with using multiple monitoring systems for continuous cardiac monitoring (CCM). The systems in question are the CardioWatch and the ECG system, which are used to monitor patients with various cardiac conditions.
#
# One of the main challenges that Sarah faces is the lack of integration between the two systems. This means that she has to log into multiple systems to view a patient's cardiac status, which can be time-consuming and prone to errors. Additionally, the systems use different alert parameters, which can lead to confusion and missed alerts.
#
# Sarah also mentions the difficulty of managing alert settings across the different systems. Each system has its own alert parameters, which means that nurses have to remember to adjust them for each patient. This can be especially challenging for new nurses who are still learning the systems.
# ...
